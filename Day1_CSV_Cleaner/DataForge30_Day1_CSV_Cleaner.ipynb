# %%
raw_data = """name,age,city
Shubham , 21 , Kathmandu
shubh, , siraha
rahul, 22,"""

with open("raw_data.csv", "w") as f:
    f.write(raw_data)

print("raw_data.csv created")
# Out:
# raw_data.csv created

# %%
import pandas as pd

# %%
df = pd.read_csv("raw_data.csv")

# %%
df
# Out:
#        name   age        city
# 0  Shubham    21    Kathmandu
# 1     shubh            siraha
# 2     rahul    22         NaN

# %%
df.isnull()
# Out:
#     name    age   city
# 0  False  False  False
# 1  False  False  False
# 2  False  False   True

# %%
df.isnull().sum()
# Out:
# name    0
# age     0
# city    1
# dtype: int64

# %%
df = df.drop_duplicates()
df
# Out:
#        name   age        city
# 0  Shubham    21    Kathmandu
# 1     shubh            siraha
# 2     rahul    22         NaN

# %%
df = df.fillna("Unknown")
df
# Out:
#        name   age        city
# 0  Shubham    21    Kathmandu
# 1     shubh            siraha
# 2     rahul    22     Unknown

# %%
df.to_csv("cleaned data.csv", index=False)
print("cleaned_data.csv saved")
# Out:
# cleaned_data.csv saved

# %%
from google.colab import files
files.download("cleaned_data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3045525722.py in <cell line: 0>()
#       1 from google.colab import files
# ----> 2 files.download("cleaned_data.csv")
#
# /usr/local/lib/python3.12/dist-packages/google/colab/files.py in download(filename)
#     231   if not _os.path.exists(filename):
#     232     msg = 'Cannot find file: {}'.format(filename)
# --> 233     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     234
#     235   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: cleaned_data.csv

# %%
# !ls
# Out:
# 'cleaned data.csv'   drive   raw_data.csv   sample_data

# %%
import pandas as pd

df = pd.read_csv("raw_data.csv")

df = df.drop_duplicates()
df = df.fillna("Unknown")

df.to_csv("cleaned_data.csv", index=False)

print("cleaned_data.csv created successfully")
# Out:
# cleaned_data.csv created successfully

# %%
from google.colab import files
files.download("cleaned_data.csv")
